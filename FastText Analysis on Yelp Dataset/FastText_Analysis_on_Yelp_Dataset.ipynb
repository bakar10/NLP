# %%
import numpy as np
import pandas as pd
import nltk
import re
from gensim.models.fasttext import FastText

# Download NLTK resources
nltk.download('wordnet')
nltk.download('omw-1.4')

# Extracting Text data from Yelp dataset
yelp_datafile = pd.read_json("/content/drive/MyDrive/yelp_academic_dataset_tip.json", lines=True)
print('List of all columns')
print(list(yelp_datafile))

# Subset data for gensim fastText model
all_sentences = list(yelp_datafile['text']) # select "text" column only
part_of_sentences = all_sentences[0:1000] # select first 1000 sample lines

# Defining lemmatizer object
lemmatizer = nltk.WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# List of all columns
# ['user_id', 'business_id', 'text', 'date', 'compliment_count']

# %%
def process_text(review):
    review = re.sub(r'\s+', ' ', review, flags=re.I) # Remove extra white space from text
    review = re.sub(r'\W', ' ', str(review)) # Remove all the special characters from text
    review = re.sub(r'\s+[a-zA-Z]\s+', ' ', review) # Remove all single characters from text
    review = re.sub(r'[^a-zA-Z\s]', '', review) # Remove any character that isn't alphabetical
    review = review.lower() # Converting to Lowercase
    # Word tokenization
    tokens = review.split()
    # Applying lemmatization
    lemma_txt = [lemmatizer.lemmatize(word) for word in tokens]
    # Drop words less than 3 characters
    tokens = [word for word in tokens if len(word) > 3]
    return tokens

# Print 10 sentences before processing
print("Sentences Before Processing:")
for i in range(10):
    print(f"Sentence {i+1}: {part_of_sentences[i]}")

# Process the sentences
cleaned_reviews = [process_text(review) for review in part_of_sentences]

# Print 10 sentences after processing
print("\nSentences After Processing:")
for i in range(10):
    print(f"Sentence {i+1}: {' '.join(cleaned_reviews[i])}")
# Out:
# Sentences Before Processing:
# Sentence 1: Avengers time with the ladies.
# Sentence 2: They have lots of good deserts and tasty cuban sandwiches
# Sentence 3: It's open even when you think it isn't
# Sentence 4: Very decent fried chicken
# Sentence 5: Appetizers.. platter special for lunch
# Sentence 6: Chili Cup + Single Cheeseburger with onion, pickle, and relish + Vanilla Coca-Cola...so far.
# Sentence 7: Saturday, Dec 7th 2013, ride Patco's Silver Sleigh w/ Santa & his elves on a decorated train into Center City. Trains leave from Lindenwold at 10am, 11:15am, & 12:30pm, and make all stops. Great for kids!
# Sentence 8: This is probably the best place in the cool Springs area to watch a game and eat
# Sentence 9: Tacos
# Sentence 10: Starbucks substitute in boring downtown Tampa. Ugh. Never again!
#
# Sentences After Processing:
# Sentence 1: avengers time with ladies
# Sentence 2: they have lots good deserts tasty cuban sandwiches
# Sentence 3: open even when think
# Sentence 4: very decent fried chicken
# Sentence 5: appetizers platter special lunch
# Sentence 6: chili single cheeseburger with onion pickle relish vanilla coca cola
# Sentence 7: saturday ride patco silver sleigh santa elves decorated train into center city trains leave from lindenwold make stops great kids
# Sentence 8: this probably best place cool springs area watch game
# Sentence 9: tacos
# Sentence 10: starbucks substitute boring downtown tampa never again

# %%
# Function to train FastText model with custom parameters
def train_Fasttext(sentences, embedding_size, window_size, min_word, down_sampling, Save_model_filename):
    fast_Text_model = FastText(sentences,
    vector_size=embedding_size,
    window=window_size,
    min_count=min_word,
    sample=down_sampling,
    workers = 4,
    sg=1,
    epochs=100)

    fast_Text_model.save(Save_model_filename)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# selected values for Training parameters
embedding_size = 300
window_size = 5
min_word = 5
down_sampling = 1e-2

train_Fasttext(cleaned_reviews, embedding_size, window_size, min_word, down_sampling, "Custom_FastText")

# Load saved gensim fastText model
fast_Text_model = FastText.load("Custom_FastText")

# %%
from gensim.models import Word2Vec

# Load saved gensim FastText model
fast_Text_model = Word2Vec.load("/content/Custom_FastText")

# %%
from gensim.models.fasttext import load_facebook_model
from gensim.models.fasttext import load_facebook_vectors

import gensim.downloader

# Load pre-trained Facebook FastText model
pretrained_model = gensim.downloader.load('fasttext-wiki-news-subwords-300')

# %%
from tabulate import tabulate

words = list(fast_Text_model.wv.key_to_index)  # Collect words from the model's vocabulary

for i in range(len(words)):
  if i % 10 == 0:  # Adjust this value if you want more or less frequent output
    print(f"Analyzing word: {words[i]}\n")

    # Getting top 10 similar and dissimilar words for custom model
    try:
      similar_words_custom = fast_Text_model.wv.most_similar(words[i], topn=10)
      opposite_words_custom = fast_Text_model.wv.most_similar(negative=[words[i]], topn=10)
    except KeyError:
      similar_words_custom = [("Word not found in vocabulary", 0.0)]
      opposite_words_custom = [("Word not found in vocabulary", 0.0)]

     #Getting top 10 similar and dissimilar words for pretrained model
    try:
      similar_words_pretrained = pretrained_model.most_similar(words[i], topn=10)
      opposite_words_pretrained = pretrained_model.most_similar(negative=[words[i]], topn=10)
    except KeyError:
      similar_words_pretrained = [("Word not found in vocabulary", 0.0)]
      opposite_words_pretrained = [("Word not found in vocabulary", 0.0)]

    # Creating tables for each category
    table_custom_similar = tabulate(similar_words_custom, headers=['Similar Word', 'Similarity'], tablefmt='github')
    table_custom_opposite = tabulate(opposite_words_custom, headers=['Opposite Word', 'Similarity'], tablefmt='github')
    table_pretrained_similar = tabulate(similar_words_pretrained, headers=['Similar Word', 'Similarity'], tablefmt='github')
    table_pretrained_opposite = tabulate(opposite_words_pretrained, headers=['Opposite Word', 'Similarity'], tablefmt='github')

    # Printing the tables
    print("Top 10 similar words (custom model):")
    print(table_custom_similar)
    print("\nTop 10 opposite words (custom model):")
    print(table_custom_opposite)
    print("\nTop 10 similar words (pre-trained model):")
    print(table_pretrained_similar)
    print("\nTop 10 opposite words (pre-trained model):")
    print(table_pretrained_opposite)
    print("\n" + "-"*40 + "\n")  # Separator for readability
# Out:
# Analyzing word: great
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | highly         |     0.460687 |
# | large          |     0.460267 |
# | local          |     0.460056 |
# | start          |     0.434377 |
# | choice         |     0.424562 |
# | server         |     0.410815 |
# | fantastic      |     0.410757 |
# | prices         |     0.407296 |
# | pickles        |     0.406203 |
# | cuban          |     0.404121 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | check           |   0.0904044  |
# | store           |   0.022808   |
# | business        |   0.00651356 |
# | should          |  -0.00163129 |
# | work            |  -0.0112569  |
# | would           |  -0.0160653  |
# | just            |  -0.0202616  |
# | yelp            |  -0.0249961  |
# | looking         |  -0.0292841  |
# | friday          |  -0.03289    |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | tremendous     |     0.836469 |
# | terrific       |     0.816918 |
# | wonderful      |     0.798327 |
# | greate         |     0.796123 |
# | greatest       |     0.791018 |
# | incredible     |     0.783962 |
# | huge           |     0.780296 |
# | marvelous      |     0.775693 |
# | fantastic      |     0.769038 |
# | enormous       |     0.767297 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | रष              |     0.524614 |
# | དུ               |     0.524059 |
# | ာ                |     0.523751 |
# | சர              |     0.523458 |
# | യത              |     0.523086 |
# | നത              |     0.521989 |
# | போக              |     0.521948 |
# | அவ              |     0.520347 |
# | കി               |     0.519525 |
# | கையை              |     0.518354 |
#
# ----------------------------------------
#
# Analyzing word: very
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | every          |     0.554412 |
# | helpful        |     0.454291 |
# | visit          |     0.451241 |
# | slow           |     0.436597 |
# | same           |     0.433943 |
# | tasty          |     0.425433 |
# | wings          |     0.414136 |
# | fast           |     0.410026 |
# | prices         |     0.400174 |
# | coming         |     0.399428 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | next            |   0.0709709  |
# | experience      |   0.049519   |
# | right           |   0.0205199  |
# | home            |   0.0107833  |
# | starbucks       |   0.0029854  |
# | free            |  -0.00451132 |
# | doing           |  -0.0160335  |
# | night           |  -0.0238724  |
# | choice          |  -0.0318049  |
# | beans           |  -0.0365299  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word    |   Similarity |
# |-----------------|--------------|
# | extremely       |     0.865397 |
# | pretty          |     0.823992 |
# | quite           |     0.807115 |
# | very-very       |     0.783552 |
# | incredibly      |     0.781851 |
# | fairly          |     0.771666 |
# | relatively      |     0.762088 |
# | remarkably      |     0.753042 |
# | -very           |     0.752938 |
# | extraordinarily |     0.751225 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | യത              |     0.436693 |
# | അന              |     0.435121 |
# | रष              |     0.433024 |
# | དུ               |     0.429859 |
# | சர              |     0.428962 |
# | നത              |     0.426394 |
# | ၌               |     0.424439 |
# | དང              |     0.423792 |
# | परन             |     0.422976 |
# | കി               |     0.422672 |
#
# ----------------------------------------
#
# Analyzing word: that
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | thai           |     0.509636 |
# | dining         |     0.494146 |
# | what           |     0.48232  |
# | cream          |     0.465021 |
# | style          |     0.452705 |
# | while          |     0.450722 |
# | didn           |     0.434626 |
# | sides          |     0.43017  |
# | until          |     0.414506 |
# | appetizer      |     0.413928 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | spot            |   0.0835883  |
# | drinks          |   0.0415807  |
# | quick           |   0.0374227  |
# | favorite        |   0.0310661  |
# | monday          |   0.0243855  |
# | special         |   0.00939869 |
# | saturday        |  -0.0200692  |
# | wednesday       |  -0.0268409  |
# | fast            |  -0.0314532  |
# | quality         |  -0.032512   |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | thaty          |     0.77604  |
# | which          |     0.764023 |
# | that--if       |     0.745459 |
# | that--even     |     0.743545 |
# | that--that     |     0.739922 |
# | thatyou        |     0.737672 |
# | thatt          |     0.731041 |
# | that--for      |     0.728073 |
# | that--but      |     0.727888 |
# | all--that      |     0.724791 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | tÃ              |     0.51301  |
# | ස               |     0.496004 |
# | นี               |     0.494723 |
# | กล              |     0.48942  |
# | சர              |     0.488638 |
# | yS              |     0.486406 |
# | วน              |     0.484586 |
# | दि               |     0.484298 |
# | Го              |     0.483111 |
# | मोदी              |     0.48193  |
#
# ----------------------------------------
#
# Analyzing word: staff
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | helpful        |     0.616651 |
# | friendly       |     0.560975 |
# | super          |     0.55576  |
# | clean          |     0.539355 |
# | quality        |     0.521677 |
# | items          |     0.518327 |
# | server         |     0.503588 |
# | seafood        |     0.500982 |
# | about          |     0.491746 |
# | selection      |     0.455571 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | full            |   0.0592804  |
# | huge            |   0.0525221  |
# | when            |   0.0398028  |
# | open            |   0.030408   |
# | snack           |  -0.00854473 |
# | during          |  -0.0320908  |
# | plus            |  -0.0342415  |
# | sandwich        |  -0.0362567  |
# | them            |  -0.0407278  |
# | monday          |  -0.0430938  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | non-staff      |     0.794896 |
# | personnel      |     0.779223 |
# | staffs         |     0.778321 |
# | staffers       |     0.758904 |
# | faculty        |     0.756091 |
# | ex-staff       |     0.752612 |
# | on-staff       |     0.749185 |
# | staffmembers   |     0.733619 |
# | staff-         |     0.72291  |
# | employees      |     0.719176 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | അന              |     0.483457 |
# | இவ              |     0.483246 |
# | വന              |     0.481619 |
# | அவ              |     0.477839 |
# | டான              |     0.473    |
# | சிந              |     0.471061 |
# | குல              |     0.46905  |
# | குக              |     0.468612 |
# | சர              |     0.468307 |
# | எம              |     0.468104 |
#
# ----------------------------------------
#
# Analyzing word: will
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | still          |     0.584195 |
# | self           |     0.528306 |
# | bring          |     0.460657 |
# | back           |     0.430951 |
# | meal           |     0.416267 |
# | burgers        |     0.409032 |
# | around         |     0.408477 |
# | loud           |     0.404103 |
# | worth          |     0.393031 |
# | spicy          |     0.392459 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | good            |   0.108015   |
# | favorite        |   0.0319541  |
# | specials        |   0.0307658  |
# | perfect         |   0.0186083  |
# | sundays         |  -0.00320764 |
# | special         |  -0.0036104  |
# | tasty           |  -0.0161295  |
# | plus            |  -0.0163467  |
# | crowd           |  -0.0197348  |
# | everything      |  -0.0275192  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | willl          |     0.809956 |
# | must           |     0.804117 |
# | should         |     0.799515 |
# | may            |     0.788148 |
# | can            |     0.772799 |
# | .will          |     0.770574 |
# | cannot         |     0.767889 |
# | would          |     0.767694 |
# | wil            |     0.750043 |
# | 'll            |     0.748483 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | tÃ              |     0.428488 |
# | यद              |     0.421969 |
# |                |     0.4184   |
# | சர              |     0.417681 |
# | കി               |     0.415439 |
# | അന              |     0.414378 |
# | پول             |     0.410758 |
# | വന              |     0.408462 |
# | கன              |     0.406741 |
# | रष              |     0.405841 |
#
# ----------------------------------------
#
# Analyzing word: beer
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | beers          |     0.731344 |
# | beef           |     0.562706 |
# | tacos          |     0.539879 |
# | been           |     0.485417 |
# | server         |     0.468585 |
# | customer       |     0.461628 |
# | pretty         |     0.44452  |
# | taco           |     0.439684 |
# | burger         |     0.41816  |
# | highly         |     0.401319 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | free            |   0.144968   |
# | spicy           |   0.0202925  |
# | enjoy           |   0.0144628  |
# | event           |   0.00909748 |
# | store           |   0.00295899 |
# | fresh           |  -0.00370023 |
# | park            |  -0.00686757 |
# | didn            |  -0.0127142  |
# | location        |  -0.0152529  |
# | there           |  -0.0264012  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | beers          |     0.850406 |
# | non-beer       |     0.767926 |
# | lager          |     0.757492 |
# | beer-brewing   |     0.752741 |
# | beer-          |     0.744575 |
# | drinks         |     0.732114 |
# | beer-making    |     0.728533 |
# | drink          |     0.726736 |
# | beerhouse      |     0.726424 |
# | brewery        |     0.722388 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | माह              |     0.395561 |
# | சர              |     0.393073 |
# | இதை              |     0.392843 |
# | வகை              |     0.391454 |
# | எனவே             |     0.389218 |
# | रष              |     0.388432 |
# | போக              |     0.388077 |
# | دهه             |     0.387848 |
# | பில              |     0.387528 |
# | அவை              |     0.386375 |
#
# ----------------------------------------
#
# Analyzing word: minutes
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | less           |     0.731596 |
# | slow           |     0.607958 |
# | took           |     0.569126 |
# | server         |     0.567672 |
# | ahead          |     0.536111 |
# | still          |     0.531526 |
# | until          |     0.52646  |
# | show           |     0.514104 |
# | coming         |     0.51001  |
# | came           |     0.506777 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | owner           |    0.0400353 |
# | house           |    0.0191053 |
# | right           |    0.0189692 |
# | drink           |    0.0147785 |
# | wednesday       |   -0.0168582 |
# | patio           |   -0.0184357 |
# | like            |   -0.0372379 |
# | must            |   -0.0429729 |
# | them            |   -0.0475208 |
# | special         |   -0.0476199 |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | seconds        |     0.815267 |
# | minute         |     0.796541 |
# | minutes-       |     0.774558 |
# | hours          |     0.758644 |
# | minuts         |     0.744886 |
# | 15minutes      |     0.734539 |
# | 30minutes      |     0.733624 |
# | 10minutes      |     0.725828 |
# | 2hours         |     0.708981 |
# | 20minutes      |     0.70048  |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | டங              |     0.40088  |
# | நண              |     0.400469 |
# | சர              |     0.398955 |
# | தம              |     0.394987 |
# | எம              |     0.394597 |
# | குக              |     0.394021 |
# | எனும             |     0.393134 |
# | அவை              |     0.391869 |
# | இங              |     0.391717 |
# | வெட              |     0.391681 |
#
# ----------------------------------------
#
# Analyzing word: atmosphere
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | music          |     0.544285 |
# | menu           |     0.530562 |
# | highly         |     0.51956  |
# | thai           |     0.518139 |
# | wine           |     0.517537 |
# | place          |     0.500919 |
# | sushi          |     0.491976 |
# | style          |     0.49095  |
# | start          |     0.486005 |
# | date           |     0.471349 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | look            |   0.0233058  |
# | back            |  -0.00473648 |
# | keep            |  -0.00693475 |
# | also            |  -0.0113676  |
# | quick           |  -0.0179647  |
# | bring           |  -0.0183198  |
# | deal            |  -0.0255829  |
# | like            |  -0.0270971  |
# | yelp            |  -0.027858   |
# | lunch           |  -0.0382906  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word     |   Similarity |
# |------------------|--------------|
# | atmospher        |     0.736933 |
# | atmospheric      |     0.72352  |
# | athmosphere      |     0.709407 |
# | atmospheres      |     0.699621 |
# | atmosphere-      |     0.698623 |
# | atmospherics     |     0.696217 |
# | atmosphere-ocean |     0.690196 |
# | ambience         |     0.689532 |
# | upper-atmosphere |     0.687386 |
# | atmoshpere       |     0.684893 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | ตั               |     0.379579 |
# | ၌               |     0.375434 |
# | s30             |     0.37447  |
# | ധ               |     0.372947 |
# | കി               |     0.372168 |
# | അന              |     0.370652 |
# | വരെ              |     0.370361 |
# | യത              |     0.369856 |
# | നല              |     0.368471 |
# | অক              |     0.368088 |
#
# ----------------------------------------
#
# Analyzing word: sure
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | make           |     0.630029 |
# | show           |     0.563367 |
# | visit          |     0.530863 |
# | slow           |     0.523061 |
# | office         |     0.498996 |
# | ahead          |     0.487612 |
# | other          |     0.48177  |
# | wasn           |     0.477739 |
# | look           |     0.469617 |
# | else           |     0.464105 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | much            |   0.0737217  |
# | green           |   0.0628275  |
# | italian         |   0.0208673  |
# | with            |   0.0195341  |
# | start           |   0.00156219 |
# | style           |  -0.00310694 |
# | bread           |  -0.0159934  |
# | have            |  -0.0262628  |
# | must            |  -0.0405321  |
# | cuban           |  -0.041613   |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | sure--         |     0.727136 |
# | forsure        |     0.722109 |
# | sure-          |     0.720265 |
# | know           |     0.711796 |
# | sure--but      |     0.706903 |
# | surely         |     0.703453 |
# | unsure         |     0.690408 |
# | aware          |     0.681865 |
# | assure         |     0.681411 |
# | sures          |     0.679117 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | ၌               |     0.430402 |
# | ಹೊಸ              |     0.429549 |
# | रष              |     0.429242 |
# | അന              |     0.427551 |
# | சர              |     0.427104 |
# | यद              |     0.425333 |
# | माह              |     0.425252 |
# | ഇന              |     0.424899 |
# | നത              |     0.424577 |
# | കി               |     0.422713 |
#
# ----------------------------------------
#
# Analyzing word: people
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | want           |     0.646111 |
# | pickles        |     0.600951 |
# | show           |     0.514577 |
# | feel           |     0.500984 |
# | keep           |     0.49062  |
# | breakfast      |     0.480462 |
# | fries          |     0.480157 |
# | while          |     0.478942 |
# | dessert        |     0.477493 |
# | else           |     0.4664   |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | wednesday       |   0.0751301  |
# | order           |   0.0449109  |
# | wine            |  -0.00171178 |
# | monday          |  -0.00497233 |
# | free            |  -0.0056619  |
# | many            |  -0.00861964 |
# | recommend       |  -0.018564   |
# | amazing         |  -0.024248   |
# | local           |  -0.024743   |
# | special         |  -0.0391919  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | peoples        |     0.800847 |
# | individuals    |     0.789671 |
# | people--all    |     0.777179 |
# | persons        |     0.77559  |
# | peope          |     0.774175 |
# | poeople        |     0.770923 |
# | people-and     |     0.763112 |
# | -people        |     0.76241  |
# | --people       |     0.761949 |
# | people--even   |     0.760457 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | വന              |     0.478533 |
# | சர              |     0.464472 |
# | पिछले             |     0.462549 |
# | அவ              |     0.462097 |
# | അന              |     0.460427 |
# | В.              |     0.459251 |
# | ‴               |     0.458337 |
# | 0T              |     0.455594 |
# | எனும             |     0.454459 |
# | ทั               |     0.453628 |
#
# ----------------------------------------
#
# Analyzing word: check
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | business       |     0.662733 |
# | should         |     0.560883 |
# | bring          |     0.55775  |
# | sign           |     0.554235 |
# | took           |     0.534101 |
# | cash           |     0.529166 |
# | sundays        |     0.526192 |
# | hours          |     0.519517 |
# | yelp           |     0.518999 |
# | long           |     0.515141 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | great           |  0.0904044   |
# | best            |  0.0760087   |
# | italian         |  0.045       |
# | town            |  0.0234647   |
# | little          |  0.0163832   |
# | ever            |  0.01405     |
# | delicious       |  0.00496188  |
# | beans           | -3.38252e-06 |
# | well            | -0.010351    |
# | cuban           | -0.0159548   |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | recheck        |     0.835831 |
# | re-check       |     0.816715 |
# | double-check   |     0.816376 |
# | checking       |     0.802008 |
# | doublecheck    |     0.794419 |
# | triple-check   |     0.769584 |
# | pre-check      |     0.767321 |
# | crosscheck     |     0.762714 |
# | check-         |     0.757614 |
# | -check         |     0.752825 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | ၌               |     0.449108 |
# | കി               |     0.446695 |
# | അന              |     0.434321 |
# | சர              |     0.43313  |
# | വന              |     0.430212 |
# | നത              |     0.428786 |
# | ႉ                |     0.426059 |
# | യത              |     0.425481 |
# | অগ              |     0.4235   |
# | തും               |     0.423015 |
#
# ----------------------------------------
#
# Analyzing word: cream
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | yogurt         |     0.621712 |
# | starbucks      |     0.595605 |
# | frozen         |     0.589991 |
# | less           |     0.583758 |
# | than           |     0.581034 |
# | most           |     0.541314 |
# | should         |     0.541285 |
# | thanks         |     0.521729 |
# | know           |     0.499528 |
# | section        |     0.493936 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | drink           |   0.104669   |
# | drinks          |   0.0689352  |
# | during          |   0.0524313  |
# | steak           |   0.0345744  |
# | wednesday       |   0.0131051  |
# | special         |   0.0086865  |
# | large           |  -0.00847538 |
# | service         |  -0.0189953  |
# | specials        |  -0.0316278  |
# | after           |  -0.0343378  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | creams         |     0.725002 |
# | creme          |     0.64773  |
# | Cream          |     0.639232 |
# | creamer        |     0.632587 |
# | cream-         |     0.62391  |
# | buttercream    |     0.621336 |
# | ice-cream      |     0.613529 |
# | creamy         |     0.605776 |
# | ice            |     0.59842  |
# | icecream       |     0.585245 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | परन             |     0.31954  |
# | تضم             |     0.315034 |
# | أى              |     0.305415 |
# | हू               |     0.303747 |
# | शकूर             |     0.302509 |
# | ၌               |     0.301294 |
# | ஓர              |     0.298779 |
# | नें               |     0.297593 |
# | அவை              |     0.297246 |
# | பில              |     0.297242 |
#
# ----------------------------------------
#
# Analyzing word: call
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | ahead          |     0.781554 |
# | snack          |     0.629096 |
# | busy           |     0.593191 |
# | else           |     0.557427 |
# | small          |     0.549985 |
# | full           |     0.54339  |
# | again          |     0.515779 |
# | close          |     0.512408 |
# | around         |     0.491699 |
# | watch          |     0.48314  |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | friendly        |    0.0699262 |
# | tacos           |    0.0216704 |
# | yummy           |   -0.0207897 |
# | good            |   -0.0266153 |
# | pickles         |   -0.0267518 |
# | onion           |   -0.0310104 |
# | beers           |   -0.0365477 |
# | helpful         |   -0.0376726 |
# | store           |   -0.0385559 |
# | area            |   -0.0407762 |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | calling        |     0.834259 |
# | calls          |     0.817524 |
# | callee         |     0.719018 |
# | caller         |     0.714522 |
# | call-          |     0.699831 |
# | called         |     0.689175 |
# | calll          |     0.685887 |
# | callers        |     0.683463 |
# | call-taker     |     0.679128 |
# | call-waiting   |     0.678677 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | यद              |     0.477141 |
# | गत              |     0.46772  |
# | சர              |     0.4667   |
# | കി               |     0.464878 |
# | रष              |     0.464356 |
# | യത              |     0.463517 |
# | দী               |     0.46322  |
# | mÃ              |     0.462882 |
# | இங              |     0.461918 |
# | माह              |     0.460043 |
#
# ----------------------------------------
#
# Analyzing word: again
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | when           |     0.532547 |
# | call           |     0.515779 |
# | world          |     0.497586 |
# | yogurt         |     0.482792 |
# | pepper         |     0.467813 |
# | self           |     0.465634 |
# | seafood        |     0.452221 |
# | seems          |     0.444681 |
# | busy           |     0.437056 |
# | wait           |     0.432397 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | wings           |    0.157714  |
# | drinks          |    0.0542195 |
# | lots            |    0.0354992 |
# | garlic          |    0.0314513 |
# | super           |    0.0215938 |
# | even            |    0.0214076 |
# | their           |    0.0199306 |
# | makes           |    0.0174231 |
# | make            |    0.0169226 |
# | only            |   -0.0105146 |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | againg         |     0.767843 |
# | again--and     |     0.754974 |
# | once           |     0.739957 |
# | again--but     |     0.72461  |
# | afterwards     |     0.716861 |
# | then           |     0.712376 |
# | soon           |     0.688714 |
# | finally        |     0.688321 |
# | now            |     0.678939 |
# | afterward      |     0.674293 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | tÃ              |     0.497479 |
# | यद              |     0.474362 |
# | சர              |     0.473244 |
# | मोदी              |     0.472813 |
# | تصل             |     0.471933 |
# | ནས              |     0.47077  |
# | དང              |     0.470174 |
# | கன              |     0.469346 |
# | शकूर             |     0.4677   |
# | ၌               |     0.4674   |
#
# ----------------------------------------
#
# Analyzing word: slow
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | took           |     0.715815 |
# | server         |     0.679063 |
# | minutes        |     0.607958 |
# | show           |     0.573448 |
# | helpful        |     0.543442 |
# | less           |     0.529041 |
# | saturday       |     0.523491 |
# | sure           |     0.523061 |
# | every          |     0.520077 |
# | quality        |     0.515445 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | green           |   0.0938756  |
# | white           |   0.0544557  |
# | love            |   0.0419929  |
# | dessert         |   0.00511336 |
# | patio           |  -0.00524166 |
# | must            |  -0.0065146  |
# | most            |  -0.00915563 |
# | much            |  -0.0260023  |
# | nothing         |  -0.0354818  |
# | house           |  -0.0354942  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | slower         |     0.812754 |
# | fast           |     0.775536 |
# | slowish        |     0.77232  |
# | slowing        |     0.769374 |
# | slow-going     |     0.753372 |
# | sluggish       |     0.745571 |
# | slowed         |     0.739183 |
# | slowpoke       |     0.738179 |
# | slow-          |     0.737903 |
# | slowy          |     0.733346 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | சர              |     0.408228 |
# | تضم             |     0.40624  |
# | جبکہ            |     0.404836 |
# | لی              |     0.404086 |
# | کہا             |     0.403601 |
# | உடனே             |     0.403511 |
# | تصل             |     0.403296 |
# | قرب             |     0.403288 |
# | ஊர              |     0.402662 |
# | கன              |     0.401515 |
#
# ----------------------------------------
#
# Analyzing word: burger
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | burgers        |     0.87741  |
# | cash           |     0.66334  |
# | huge           |     0.581227 |
# | brunch         |     0.538156 |
# | some           |     0.527198 |
# | look           |     0.526597 |
# | snack          |     0.512785 |
# | early          |     0.509581 |
# | bring          |     0.491387 |
# | order          |     0.487465 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | love            |   0.0382934  |
# | store           |  -0.00179495 |
# | fries           |  -0.0150939  |
# | miss            |  -0.0248247  |
# | italian         |  -0.0255713  |
# | from            |  -0.0342995  |
# | world           |  -0.0390715  |
# | yummy           |  -0.0552587  |
# | green           |  -0.0623868  |
# | want            |  -0.063812   |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | hamburger      |     0.858178 |
# | burgers        |     0.825739 |
# | cheeseburger   |     0.779473 |
# | beefburger     |     0.734371 |
# | hotdog         |     0.734115 |
# | hamburgers     |     0.729332 |
# | sandwich       |     0.716846 |
# | fast-food      |     0.684972 |
# | steak          |     0.682761 |
# | fries          |     0.673972 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | परन             |     0.37457  |
# | அவை              |     0.371738 |
# | வகை              |     0.369453 |
# | எனும             |     0.366096 |
# | இதை              |     0.365724 |
# | കി               |     0.365338 |
# | शकूर             |     0.365057 |
# | அத              |     0.364883 |
# | அவ              |     0.362002 |
# | களது             |     0.361075 |
#
# ----------------------------------------
#
# Analyzing word: ordered
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | order          |     0.685011 |
# | crispy         |     0.570806 |
# | white          |     0.548187 |
# | pepper         |     0.541098 |
# | much           |     0.533208 |
# | should         |     0.532861 |
# | beef           |     0.505191 |
# | appetizer      |     0.500609 |
# | taco           |     0.497269 |
# | roll           |     0.493034 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | cheap           |    0.0829947 |
# | choice          |    0.0217048 |
# | fast            |    0.0131936 |
# | service         |    0.0129006 |
# | sunday          |   -0.0239592 |
# | even            |   -0.0295857 |
# | check           |   -0.0349399 |
# | driver          |   -0.036716  |
# | brunch          |   -0.0375191 |
# | park            |   -0.0376421 |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | ordering       |     0.739714 |
# | countermanded  |     0.731414 |
# | order          |     0.726431 |
# | re-ordered     |     0.699899 |
# | orders         |     0.687662 |
# | arranged       |     0.684058 |
# | back-ordered   |     0.677174 |
# | unordered      |     0.665965 |
# | preordered     |     0.663969 |
# | reordered      |     0.659554 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | ღღ              |     0.42699  |
# | சர              |     0.426844 |
# | tÃ              |     0.425688 |
# | இங              |     0.422737 |
# | यद              |     0.422026 |
# | நண              |     0.421678 |
# | கன              |     0.42019  |
# | அங              |     0.41814  |
# | ஊர              |     0.416933 |
# | சிந              |     0.416224 |
#
# ----------------------------------------
#
# Analyzing word: customer
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | worst          |     0.696242 |
# | driver         |     0.669097 |
# | fantastic      |     0.606186 |
# | highly         |     0.586965 |
# | half           |     0.568043 |
# | service        |     0.558311 |
# | cuban          |     0.542694 |
# | owner          |     0.538875 |
# | monday         |     0.526547 |
# | could          |     0.51803  |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | plus            |    0.0089326 |
# | love            |   -0.0251587 |
# | should          |   -0.0410029 |
# | items           |   -0.043205  |
# | salad           |   -0.0488489 |
# | spicy           |   -0.0511361 |
# | check           |   -0.060389  |
# | chicken         |   -0.0638508 |
# | free            |   -0.0688494 |
# | location        |   -0.0739937 |
#
# Top 10 similar words (pre-trained model):
# | Similar Word     |   Similarity |
# |------------------|--------------|
# | customers        |     0.807387 |
# | non-customer     |     0.776247 |
# | customer-care    |     0.751541 |
# | end-customer     |     0.748808 |
# | customer-service |     0.741092 |
# | customer-        |     0.733353 |
# | customer-support |     0.722938 |
# | customer-related |     0.719629 |
# | customer-facing  |     0.71886  |
# | customer-based   |     0.707408 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | വന              |     0.443401 |
# | मय              |     0.441139 |
# | അന              |     0.441137 |
# | குல              |     0.439764 |
# | കി               |     0.43703  |
# | அவ              |     0.436806 |
# | பங              |     0.435221 |
# | യത              |     0.435129 |
# | வன              |     0.434547 |
# | णन              |     0.434075 |
#
# ----------------------------------------
#
# Analyzing word: experience
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | choice         |     0.594459 |
# | office         |     0.528235 |
# | yogurt         |     0.526233 |
# | going          |     0.502612 |
# | doing          |     0.495302 |
# | before         |     0.486617 |
# | there          |     0.483428 |
# | family         |     0.476458 |
# | starbucks      |     0.466808 |
# | section        |     0.466788 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | very            |   0.049519   |
# | drink           |   0.01771    |
# | special         |   0.015339   |
# | full            |   0.0113266  |
# | small           |  -0.00404038 |
# | nothing         |  -0.00737764 |
# | makes           |  -0.0275995  |
# | menu            |  -0.0296894  |
# | ordered         |  -0.0385303  |
# | crispy          |  -0.0415873  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word    |   Similarity |
# |-----------------|--------------|
# | experiences     |     0.84835  |
# | reexperience    |     0.772816 |
# | expeience       |     0.763283 |
# | experienced     |     0.756241 |
# | experiance      |     0.751971 |
# | experient       |     0.749866 |
# | experience--and |     0.745387 |
# | re-experience   |     0.743075 |
# | experienc       |     0.739184 |
# | experiece       |     0.736727 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | വന              |     0.523013 |
# | சர              |     0.508541 |
# | യത              |     0.507091 |
# | ബ               |     0.505413 |
# | எண              |     0.505168 |
# | ധ               |     0.50415  |
# | അന              |     0.503318 |
# | ഗ               |     0.502498 |
# | ಹೊಸ              |     0.500989 |
# | கன              |     0.500699 |
#
# ----------------------------------------
#
# Analyzing word: spring
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | rolls          |     0.843439 |
# | roll           |     0.805507 |
# | thai           |     0.785718 |
# | soup           |     0.691668 |
# | shrimp         |     0.640148 |
# | start          |     0.632228 |
# | crispy         |     0.625743 |
# | tacos          |     0.589349 |
# | style          |     0.588259 |
# | tasty          |     0.547916 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | seems           |   0.0453106  |
# | favorite        |   0.0257041  |
# | sundays         |  -0.00405987 |
# | street          |  -0.010353   |
# | office          |  -0.0152334  |
# | your            |  -0.0189558  |
# | until           |  -0.0343318  |
# | weekend         |  -0.037662   |
# | sign            |  -0.0572409  |
# | same            |  -0.0690316  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | summer         |     0.82462  |
# | autumn         |     0.814831 |
# | winter         |     0.763155 |
# | fall           |     0.748721 |
# | summer-fall    |     0.744553 |
# | spring-summer  |     0.744472 |
# | mid-spring     |     0.742064 |
# | mid-summer     |     0.741751 |
# | spring-        |     0.740603 |
# | springlike     |     0.72923  |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | அவ              |     0.479569 |
# | கன              |     0.476536 |
# | சர              |     0.476217 |
# | போக              |     0.476032 |
# | அங              |     0.473224 |
# | இதை              |     0.472426 |
# | இங              |     0.47239  |
# | பம              |     0.47114  |
# | வைக              |     0.47003  |
# | டான              |     0.469195 |
#
# ----------------------------------------
#
# Analyzing word: show
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | business       |     0.724491 |
# | until          |     0.66542  |
# | know           |     0.661679 |
# | should         |     0.639026 |
# | office         |     0.626871 |
# | wasn           |     0.624804 |
# | make           |     0.619728 |
# | ahead          |     0.611348 |
# | less           |     0.594212 |
# | want           |     0.579482 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | start           |   0.0693722  |
# | local           |   0.031013   |
# | brunch          |   0.0304028  |
# | cuban           |   0.0272838  |
# | beans           |   0.00927758 |
# | selection       |  -0.0038772  |
# | burgers         |  -0.0186882  |
# | coffee          |  -0.0223603  |
# | highly          |  -0.0261941  |
# | area            |  -0.0407348  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | shows          |     0.826713 |
# | showing        |     0.743478 |
# | mixshow        |     0.737666 |
# | demonstrate    |     0.736355 |
# | -show          |     0.732538 |
# | non-show       |     0.727647 |
# | clip-show      |     0.715177 |
# | shown          |     0.713135 |
# | showed         |     0.710545 |
# | aftershow      |     0.706817 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | यद              |     0.503935 |
# | വന              |     0.502371 |
# | சர              |     0.500854 |
# | ബ               |     0.499371 |
# | रष              |     0.49681  |
# | मोदी              |     0.496485 |
# | ധ               |     0.495787 |
# | ഗ               |     0.4953   |
# | আত              |     0.493454 |
# | செங              |     0.493438 |
#
# ----------------------------------------
#
# Analyzing word: getting
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | pepper         |     0.612084 |
# | house          |     0.554653 |
# | fish           |     0.551849 |
# | years          |     0.542688 |
# | going          |     0.530922 |
# | busy           |     0.528261 |
# | watch          |     0.526294 |
# | week           |     0.525521 |
# | clean          |     0.520819 |
# | appetizer      |     0.513179 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | loud            |  0.0727856   |
# | really          |  0.0220722   |
# | monday          |  0.0115727   |
# | section         |  0.00347284  |
# | lots            |  0.000735117 |
# | live            | -0.00422686  |
# | they            | -0.00507657  |
# | tasty           | -0.0252213   |
# | open            | -0.0272747   |
# | crowd           | -0.031587    |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | gettting       |     0.86044  |
# | geting         |     0.826283 |
# | get            |     0.797308 |
# | gettng         |     0.781712 |
# | going          |     0.752872 |
# | having         |     0.747485 |
# | gotten         |     0.736165 |
# | gettign        |     0.734709 |
# | got            |     0.733735 |
# | gettings       |     0.724665 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | tÃ              |     0.456809 |
# | Го              |     0.449292 |
# | रष              |     0.44183  |
# | वं               |     0.441093 |
# | mÃ              |     0.437082 |
# | ಹೊಸ              |     0.436764 |
# | அக              |     0.434064 |
# | சர              |     0.433401 |
# | सद              |     0.430054 |
# | வண              |     0.430045 |
#
# ----------------------------------------
#
# Analyzing word: roll
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | rolls          |     0.856542 |
# | spring         |     0.805507 |
# | thai           |     0.699917 |
# | crispy         |     0.698683 |
# | soup           |     0.648513 |
# | style          |     0.600416 |
# | shrimp         |     0.593006 |
# | super          |     0.575108 |
# | onion          |     0.568972 |
# | spicy          |     0.56433  |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | come            |    0.0229733 |
# | favorite        |   -0.020026  |
# | weekend         |   -0.038384  |
# | cool            |   -0.0418124 |
# | night           |   -0.0422981 |
# | seems           |   -0.0443341 |
# | your            |   -0.0506153 |
# | last            |   -0.0545895 |
# | birthday        |   -0.0765228 |
# | huge            |   -0.0774856 |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | rolls          |     0.792669 |
# | rolling        |     0.75347  |
# | re-roll        |     0.711459 |
# | roll.          |     0.70471  |
# | rolled         |     0.691539 |
# | rollin         |     0.669309 |
# | rollie         |     0.665803 |
# | rolling-pin    |     0.665134 |
# | rolle          |     0.665007 |
# | unroll         |     0.661768 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | قوی             |     0.439241 |
# | تضم             |     0.434505 |
# | রহ              |     0.432138 |
# | В.              |     0.429756 |
# | ღღ              |     0.429595 |
# | Ова             |     0.428376 |
# | থার              |     0.428312 |
# | ঠিত              |     0.427442 |
# | قرب             |     0.426064 |
# | أسس             |     0.425686 |
#
# ----------------------------------------
#
# Analyzing word: authentic
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | home           |     0.681632 |
# | crowd          |     0.634768 |
# | selection      |     0.551221 |
# | live           |     0.546132 |
# | style          |     0.54307  |
# | small          |     0.533841 |
# | town           |     0.523254 |
# | eating         |     0.513939 |
# | down           |     0.500345 |
# | most           |     0.499956 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | birthday        |   0.0167419  |
# | which           |  -0.00754819 |
# | salad           |  -0.0165629  |
# | after           |  -0.0252055  |
# | before          |  -0.025886   |
# | many            |  -0.032977   |
# | pizza           |  -0.0357034  |
# | saturday        |  -0.0408613  |
# | experience      |  -0.0519935  |
# | side            |  -0.0591765  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word       |   Similarity |
# |--------------------|--------------|
# | non-authentic      |     0.798891 |
# | genuine            |     0.771255 |
# | authentical        |     0.76842  |
# | authentically      |     0.766654 |
# | authenticy         |     0.766381 |
# | inauthentic        |     0.765197 |
# | authenticity       |     0.739614 |
# | unauthentic        |     0.727663 |
# | authenticated      |     0.710345 |
# | well-authenticated |     0.701517 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | சர              |     0.420525 |
# | തും               |     0.420181 |
# | യത              |     0.418568 |
# | ബ               |     0.416452 |
# | போக              |     0.416021 |
# | பில              |     0.414816 |
# | இங              |     0.414218 |
# | നല              |     0.412306 |
# | അന              |     0.412105 |
# | அளவு             |     0.411579 |
#
# ----------------------------------------
#
# Analyzing word: choice
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | yogurt         |     0.682635 |
# | frozen         |     0.645032 |
# | must           |     0.616405 |
# | experience     |     0.594459 |
# | miss           |     0.559819 |
# | breakfast      |     0.526434 |
# | also           |     0.522472 |
# | fantastic      |     0.505635 |
# | doing          |     0.504144 |
# | dessert        |     0.504064 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | today           |    0.0660438 |
# | find            |    0.0591239 |
# | crispy          |    0.0465829 |
# | cash            |    0.0287518 |
# | ordered         |    0.0217048 |
# | deal            |    0.0143739 |
# | order           |   -0.0124574 |
# | night           |   -0.0168683 |
# | full            |   -0.0174516 |
# | half            |   -0.0253431 |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | choices        |     0.837922 |
# | choice-        |     0.752803 |
# | choosing       |     0.748654 |
# | choose         |     0.741813 |
# | choise         |     0.735611 |
# | preference     |     0.73556  |
# | option         |     0.730843 |
# | choice-based   |     0.713657 |
# | chooser        |     0.70816  |
# | choice-making  |     0.703725 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | रष              |     0.506938 |
# | यद              |     0.499391 |
# | परन             |     0.497981 |
# | मय              |     0.497901 |
# | جبکہ            |     0.495425 |
# | അന              |     0.494702 |
# | कक              |     0.493264 |
# | യത              |     0.492561 |
# | মায              |     0.492004 |
# | ങള              |     0.490664 |
#
# ----------------------------------------
#
# Analyzing word: should
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | less           |     0.659623 |
# | know           |     0.659095 |
# | show           |     0.639026 |
# | would          |     0.632916 |
# | over           |     0.615973 |
# | business       |     0.603823 |
# | pepper         |     0.593121 |
# | didn           |     0.590245 |
# | check          |     0.560883 |
# | could          |     0.548405 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | burritos        |   0.0345812  |
# | best            |   0.0320838  |
# | great           |  -0.00163128 |
# | large           |  -0.0052074  |
# | beans           |  -0.0101247  |
# | fantastic       |  -0.0139538  |
# | cuban           |  -0.014034   |
# | park            |  -0.024078   |
# | highly          |  -0.025225   |
# | brunch          |  -0.025571   |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | must           |     0.854742 |
# | shoiuld        |     0.826342 |
# | ought          |     0.824375 |
# | could          |     0.819258 |
# | shouuld        |     0.816713 |
# | chould         |     0.809027 |
# | shoould        |     0.800005 |
# | will           |     0.799515 |
# | coould         |     0.796725 |
# | would          |     0.79506  |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | சர              |     0.460716 |
# | കി               |     0.451447 |
# | यद              |     0.447378 |
# | கன              |     0.445369 |
# | അന              |     0.443866 |
# |                |     0.443415 |
# | تصل             |     0.442215 |
# | വന              |     0.441783 |
# | எனும             |     0.440116 |
# | வீட              |     0.439891 |
#
# ----------------------------------------
#
# Analyzing word: wednesday
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | monday         |     0.620745 |
# | half           |     0.617528 |
# | tacos          |     0.567864 |
# | highly         |     0.553023 |
# | wine           |     0.544462 |
# | large          |     0.540885 |
# | birthday       |     0.535343 |
# | price          |     0.504628 |
# | area           |     0.50093  |
# | brunch         |     0.497969 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | people          |   0.0751301  |
# | thing           |   0.0404754  |
# | enjoy           |   0.0308654  |
# | cream           |   0.0131051  |
# | everything      |   0.00233712 |
# | coming          |   0.00149928 |
# | parking         |  -0.00578612 |
# | while           |  -0.0103774  |
# | like            |  -0.0112507  |
# | make            |  -0.0118792  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | tuesday        |     0.867837 |
# | thursday       |     0.86231  |
# | monday         |     0.851432 |
# | friday         |     0.825471 |
# | saturday       |     0.822274 |
# | sunday         |     0.802302 |
# | wednesdays     |     0.800419 |
# | tuesdays       |     0.73122  |
# | afternoon.     |     0.687749 |
# | sundays        |     0.684668 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | लिखे              |     0.333283 |
# | संत              |     0.332184 |
# | قوی             |     0.329692 |
# | ума             |     0.321412 |
# | Го              |     0.321327 |
# | کہا             |     0.318944 |
# | ၌               |     0.317409 |
# | Лукьянов        |     0.316211 |
# | དེ               |     0.315662 |
# | হন              |     0.315385 |
#
# ----------------------------------------
#
# Analyzing word: huge
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | cash           |     0.654453 |
# | burger         |     0.581227 |
# | busy           |     0.571463 |
# | beef           |     0.550822 |
# | snack          |     0.515153 |
# | came           |     0.514717 |
# | know           |     0.506044 |
# | appetizer      |     0.498522 |
# | ahead          |     0.497025 |
# | some           |     0.491961 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | items           |   0.0551527  |
# | staff           |   0.0525221  |
# | friendly        |   0.0243125  |
# | super           |  -0.00774109 |
# | fantastic       |  -0.0105588  |
# | most            |  -0.0172207  |
# | well            |  -0.0255809  |
# | food            |  -0.0402514  |
# | about           |  -0.0450667  |
# | store           |  -0.047903   |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | enormous       |     0.895093 |
# | big            |     0.871693 |
# | massive        |     0.865533 |
# | gigantic       |     0.856648 |
# | humungous      |     0.8307   |
# | large          |     0.82901  |
# | huger          |     0.828797 |
# | tremendous     |     0.811341 |
# | sizeable       |     0.797141 |
# | immense        |     0.791275 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | قصد             |     0.454561 |
# | रष              |     0.452879 |
# | हू               |     0.451074 |
# | नें               |     0.450886 |
# | تضم             |     0.450786 |
# | கையை              |     0.44841  |
# | اون             |     0.446581 |
# | قرب             |     0.446464 |
# | तै               |     0.445439 |
# | ளன              |     0.443497 |
#
# ----------------------------------------
#
# Analyzing word: feel
#
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | cheese         |     0.55863  |
# | pickles        |     0.549492 |
# | work           |     0.527746 |
# | street         |     0.525736 |
# | could          |     0.514399 |
# | frozen         |     0.508922 |
# | people         |     0.500984 |
# | beers          |     0.497842 |
# | didn           |     0.485118 |
# | miss           |     0.485078 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | anything        |   0.0518327  |
# | order           |   0.0312116  |
# | best            |  -0.00123811 |
# | fresh           |  -0.00548541 |
# | again           |  -0.0359372  |
# | thing           |  -0.0474343  |
# | call            |  -0.0665831  |
# | free            |  -0.0696502  |
# | fish            |  -0.0785536  |
# | area            |  -0.0787126  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | feels          |     0.799645 |
# | felt           |     0.767971 |
# | feeling        |     0.754766 |
# | feel-          |     0.737868 |
# | feeel          |     0.735455 |
# | think          |     0.708247 |
# | gut-feel       |     0.70729  |
# | feel.          |     0.672316 |
# | believe        |     0.663334 |
# | feely          |     0.648547 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | मोदी              |     0.432019 |
# | അന              |     0.420088 |
# | உங              |     0.419861 |
# | रष              |     0.417347 |
# | சர              |     0.417094 |
# | തിൽ              |     0.415904 |
# | கன              |     0.415763 |
# | دهه             |     0.414442 |
# | വരെ              |     0.413825 |
# | മറ              |     0.413429 |
#
# ----------------------------------------
